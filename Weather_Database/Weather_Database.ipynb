# %%
# Import dependencies
import pandas as pd
import numpy as np
import sys
from config import weather_api_key
import requests

# %%
#Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
#Get the nearest city using the citipy module.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval         ")
print("---------------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
        # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        
        
       
        # Append the city information into the city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})
        
    # If an error is experience, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------------------")
print("Data Retrieval Complete            ")
print("-----------------------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | geraldton
# Processing Record 4 of Set 1 | pevek
# Processing Record 5 of Set 1 | kysyl-syr
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | asau
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | champerico
# Processing Record 10 of Set 1 | cherskiy
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 1 | raudeberg
# Processing Record 15 of Set 1 | caetite
# Processing Record 16 of Set 1 | benguela
# Processing Record 17 of Set 1 | mar del plata
# Processing Record 18 of Set 1 | araguacu
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | jinchang
# Processing Record 26 of Set 1 | hasaki
# Processing Record 27 of Set 1 | safita
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | nhulunbuy
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | clyde river
# Processing Record 34 of Set 1 | bandarbeyla
# Processing Record 35 of Set 1 | shakiso
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | panshi
# Processing Record 38 of Set 1 | cidreira
# Processing Record 39 of Set 1 | badvel
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | vizianagaram
# Processing Record 43 of Set 1 | bairiki
# Processing Record 44 of Set 1 | kerteh
# City not found. Skipping...
# Processing Record 45 of Set 1 | pringsewu
# Processing Record 46 of Set 1 | saint-augustin
# Processing Record 47 of Set 1 | port arthur
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | rioja
# Processing Record 4 of Set 2 | ribeira grande
# Processing Record 5 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 2 | gangotri
# City not found. Skipping...
# Processing Record 7 of Set 2 | fortuna
# Processing Record 8 of Set 2 | verkhoyansk
# Processing Record 9 of Set 2 | tasiilaq
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | plainview
# Processing Record 13 of Set 2 | haimen
# Processing Record 14 of Set 2 | iqaluit
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | tawau
# Processing Record 17 of Set 2 | whitehorse
# Processing Record 18 of Set 2 | dunedin
# Processing Record 19 of Set 2 | mazamari
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | port hardy
# Processing Record 22 of Set 2 | itacoatiara
# Processing Record 23 of Set 2 | nanortalik
# Processing Record 24 of Set 2 | pierre
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | comodoro rivadavia
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | zatoka
# Processing Record 29 of Set 2 | alyangula
# Processing Record 30 of Set 2 | san patricio
# Processing Record 31 of Set 2 | san joaquin
# Processing Record 32 of Set 2 | vila franca do campo
# Processing Record 33 of Set 2 | new norfolk
# Processing Record 34 of Set 2 | dowa
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | tiarei
# Processing Record 37 of Set 2 | taltal
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | plettenberg bay
# Processing Record 40 of Set 2 | kotido
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | saint-georges
# Processing Record 43 of Set 2 | narsaq
# Processing Record 44 of Set 2 | zhigansk
# Processing Record 45 of Set 2 | hobyo
# Processing Record 46 of Set 2 | maumere
# Processing Record 47 of Set 2 | zenzeli
# Processing Record 48 of Set 2 | hermanus
# Processing Record 49 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 2 | scottsboro
# Processing Record 1 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 3 | bilma
# Processing Record 3 of Set 3 | marawi
# Processing Record 4 of Set 3 | bambous virieux
# Processing Record 5 of Set 3 | hobart
# Processing Record 6 of Set 3 | skjervoy
# Processing Record 7 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 3 | karasjok
# Processing Record 9 of Set 3 | butaritari
# Processing Record 10 of Set 3 | sakaiminato
# Processing Record 11 of Set 3 | haverfordwest
# Processing Record 12 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 3 | airai
# Processing Record 14 of Set 3 | porto velho
# Processing Record 15 of Set 3 | grand gaube
# Processing Record 16 of Set 3 | kunming
# Processing Record 17 of Set 3 | severo-kurilsk
# Processing Record 18 of Set 3 | necochea
# Processing Record 19 of Set 3 | raozan
# City not found. Skipping...
# Processing Record 20 of Set 3 | oxford
# Processing Record 21 of Set 3 | tezu
# Processing Record 22 of Set 3 | yenagoa
# Processing Record 23 of Set 3 | phek
# Processing Record 24 of Set 3 | mahebourg
# Processing Record 25 of Set 3 | khatanga
# Processing Record 26 of Set 3 | nikolskoye
# Processing Record 27 of Set 3 | bethel
# Processing Record 28 of Set 3 | sitka
# Processing Record 29 of Set 3 | trapani
# Processing Record 30 of Set 3 | imbituba
# Processing Record 31 of Set 3 | isangel
# Processing Record 32 of Set 3 | kibakwe
# Processing Record 33 of Set 3 | mombaca
# Processing Record 34 of Set 3 | saskylakh
# Processing Record 35 of Set 3 | viedma
# Processing Record 36 of Set 3 | souillac
# Processing Record 37 of Set 3 | mayumba
# Processing Record 38 of Set 3 | ilulissat
# Processing Record 39 of Set 3 | arlit
# Processing Record 40 of Set 3 | mataura
# Processing Record 41 of Set 3 | ahar
# Processing Record 42 of Set 3 | sandwick
# Processing Record 43 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 3 | adrar
# Processing Record 45 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 3 | yulara
# Processing Record 47 of Set 3 | san quintin
# Processing Record 48 of Set 3 | mouzakion
# City not found. Skipping...
# Processing Record 49 of Set 3 | ponta do sol
# Processing Record 50 of Set 3 | kataysk
# Processing Record 1 of Set 4 | gbarnga
# Processing Record 2 of Set 4 | matagami
# Processing Record 3 of Set 4 | qui nhon
# Processing Record 4 of Set 4 | halapitan
# Processing Record 5 of Set 4 | xuanhua
# Processing Record 6 of Set 4 | kenai
# Processing Record 7 of Set 4 | meulaboh
# Processing Record 8 of Set 4 | presidencia roque saenz pena
# Processing Record 9 of Set 4 | svolvaer
# Processing Record 10 of Set 4 | mlimba
# Processing Record 11 of Set 4 | valparaiso
# Processing Record 12 of Set 4 | batangafo
# Processing Record 13 of Set 4 | deputatskiy
# Processing Record 14 of Set 4 | alofi
# Processing Record 15 of Set 4 | caravelas
# Processing Record 16 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 17 of Set 4 | lagoa
# Processing Record 18 of Set 4 | muros
# Processing Record 19 of Set 4 | banda aceh
# Processing Record 20 of Set 4 | neiafu
# Processing Record 21 of Set 4 | zermatt
# Processing Record 22 of Set 4 | margate
# Processing Record 23 of Set 4 | muyezerskiy
# Processing Record 24 of Set 4 | ewa beach
# Processing Record 25 of Set 4 | voyvozh
# Processing Record 26 of Set 4 | lompoc
# Processing Record 27 of Set 4 | husavik
# Processing Record 28 of Set 4 | fairbanks
# Processing Record 29 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 30 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 31 of Set 4 | ballina
# Processing Record 32 of Set 4 | najran
# Processing Record 33 of Set 4 | touros
# Processing Record 34 of Set 4 | kaitangata
# Processing Record 35 of Set 4 | mustasaari
# Processing Record 36 of Set 4 | esperance
# Processing Record 37 of Set 4 | la ronge
# Processing Record 38 of Set 4 | yichang
# Processing Record 39 of Set 4 | grindavik
# Processing Record 40 of Set 4 | hofn
# Processing Record 41 of Set 4 | zalantun
# Processing Record 42 of Set 4 | ancud
# Processing Record 43 of Set 4 | biak
# Processing Record 44 of Set 4 | saint anthony
# Processing Record 45 of Set 4 | chuy
# Processing Record 46 of Set 4 | iskateley
# Processing Record 47 of Set 4 | ouro preto do oeste
# Processing Record 48 of Set 4 | kruisfontein
# Processing Record 49 of Set 4 | leningradskiy
# Processing Record 50 of Set 4 | salalah
# Processing Record 1 of Set 5 | carnarvon
# Processing Record 2 of Set 5 | alice springs
# Processing Record 3 of Set 5 | talara
# Processing Record 4 of Set 5 | wajir
# Processing Record 5 of Set 5 | daru
# Processing Record 6 of Set 5 | elizabeth city
# Processing Record 7 of Set 5 | norman wells
# Processing Record 8 of Set 5 | taganak
# Processing Record 9 of Set 5 | ronne
# Processing Record 10 of Set 5 | broome
# Processing Record 11 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 5 | russell
# Processing Record 13 of Set 5 | richards bay
# Processing Record 14 of Set 5 | lexington
# Processing Record 15 of Set 5 | khilok
# Processing Record 16 of Set 5 | harper
# Processing Record 17 of Set 5 | kaeo
# Processing Record 18 of Set 5 | bubaque
# Processing Record 19 of Set 5 | le moule
# Processing Record 20 of Set 5 | havre-saint-pierre
# Processing Record 21 of Set 5 | tabou
# Processing Record 22 of Set 5 | balikpapan
# Processing Record 23 of Set 5 | leeston
# Processing Record 24 of Set 5 | katha
# City not found. Skipping...
# Processing Record 25 of Set 5 | provideniya
# Processing Record 26 of Set 5 | chokurdakh
# Processing Record 27 of Set 5 | bosaso
# Processing Record 28 of Set 5 | teguldet
# Processing Record 29 of Set 5 | saldanha
# Processing Record 30 of Set 5 | puerto escondido
# Processing Record 31 of Set 5 | barra do garcas
# Processing Record 32 of Set 5 | rio gallegos
# Processing Record 33 of Set 5 | shizunai
# Processing Record 34 of Set 5 | kapaa
# Processing Record 35 of Set 5 | salaberry-de-valleyfield
# Processing Record 36 of Set 5 | zachary
# Processing Record 37 of Set 5 | praia da vitoria
# Processing Record 38 of Set 5 | bima
# Processing Record 39 of Set 5 | mahina
# Processing Record 40 of Set 5 | krasnovishersk
# Processing Record 41 of Set 5 | taft
# Processing Record 42 of Set 5 | laurel
# Processing Record 43 of Set 5 | eureka
# Processing Record 44 of Set 5 | kafanchan
# Processing Record 45 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 46 of Set 5 | saint george
# Processing Record 47 of Set 5 | bengkulu
# Processing Record 48 of Set 5 | nishihara
# Processing Record 49 of Set 5 | kangaatsiaq
# Processing Record 50 of Set 5 | khandyga
# Processing Record 1 of Set 6 | okhotsk
# Processing Record 2 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 6 | jining
# Processing Record 4 of Set 6 | kirakira
# Processing Record 5 of Set 6 | makakilo city
# Processing Record 6 of Set 6 | yingzhong
# City not found. Skipping...
# Processing Record 7 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 6 | kazanlak
# Processing Record 9 of Set 6 | gitega
# Processing Record 10 of Set 6 | port moresby
# Processing Record 11 of Set 6 | ugoofaaru
# Processing Record 12 of Set 6 | buraydah
# Processing Record 13 of Set 6 | longyearbyen
# Processing Record 14 of Set 6 | north platte
# Processing Record 15 of Set 6 | port-gentil
# Processing Record 16 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 17 of Set 6 | pemangkat
# Processing Record 18 of Set 6 | sehithwa
# Processing Record 19 of Set 6 | xiaoyi
# Processing Record 20 of Set 6 | sibolga
# Processing Record 21 of Set 6 | port blair
# Processing Record 22 of Set 6 | labuhan
# Processing Record 23 of Set 6 | codrington
# Processing Record 24 of Set 6 | bereda
# Processing Record 25 of Set 6 | asfi
# Processing Record 26 of Set 6 | hovd
# Processing Record 27 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 6 | pokhara
# Processing Record 29 of Set 6 | inta
# Processing Record 30 of Set 6 | guarapari
# Processing Record 31 of Set 6 | ulladulla
# Processing Record 32 of Set 6 | balakhta
# Processing Record 33 of Set 6 | dudinka
# Processing Record 34 of Set 6 | north bend
# Processing Record 35 of Set 6 | honiara
# Processing Record 36 of Set 6 | pisco
# Processing Record 37 of Set 6 | flinders
# Processing Record 38 of Set 6 | shenjiamen
# Processing Record 39 of Set 6 | nova esperanca
# Processing Record 40 of Set 6 | rawson
# Processing Record 41 of Set 6 | corinto
# Processing Record 42 of Set 6 | burica
# City not found. Skipping...
# Processing Record 43 of Set 6 | avarua
# Processing Record 44 of Set 6 | zhezkazgan
# Processing Record 45 of Set 6 | kitimat
# Processing Record 46 of Set 6 | upington
# Processing Record 47 of Set 6 | kiama
# Processing Record 48 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 6 | sao joao da barra
# Processing Record 50 of Set 6 | victoria
# Processing Record 1 of Set 7 | kurchum
# Processing Record 2 of Set 7 | gigmoto
# Processing Record 3 of Set 7 | katobu
# Processing Record 4 of Set 7 | madang
# Processing Record 5 of Set 7 | preobrazheniye
# Processing Record 6 of Set 7 | manavalakurichi
# Processing Record 7 of Set 7 | byron bay
# Processing Record 8 of Set 7 | ibra
# Processing Record 9 of Set 7 | aklavik
# Processing Record 10 of Set 7 | kuybyshevo
# Processing Record 11 of Set 7 | sambava
# Processing Record 12 of Set 7 | lavrentiya
# Processing Record 13 of Set 7 | sioux lookout
# Processing Record 14 of Set 7 | camana
# Processing Record 15 of Set 7 | aranos
# Processing Record 16 of Set 7 | kloulklubed
# Processing Record 17 of Set 7 | olden
# Processing Record 18 of Set 7 | aktash
# Processing Record 19 of Set 7 | kadirli
# Processing Record 20 of Set 7 | apud
# Processing Record 21 of Set 7 | montgomery
# Processing Record 22 of Set 7 | potamia
# Processing Record 23 of Set 7 | atambua
# Processing Record 24 of Set 7 | milosesti
# Processing Record 25 of Set 7 | taoudenni
# Processing Record 26 of Set 7 | upernavik
# Processing Record 27 of Set 7 | truth or consequences
# Processing Record 28 of Set 7 | hebertville
# City not found. Skipping...
# Processing Record 29 of Set 7 | sarankhola
# Processing Record 30 of Set 7 | guerrero negro
# Processing Record 31 of Set 7 | paranaiba
# Processing Record 32 of Set 7 | arica
# Processing Record 33 of Set 7 | la rioja
# Processing Record 34 of Set 7 | bolshevik
# Processing Record 35 of Set 7 | mehamn
# Processing Record 36 of Set 7 | bauru
# Processing Record 37 of Set 7 | palmer
# Processing Record 38 of Set 7 | constitucion
# Processing Record 39 of Set 7 | puyang
# Processing Record 40 of Set 7 | altamira
# Processing Record 41 of Set 7 | tyup
# Processing Record 42 of Set 7 | bulungu
# Processing Record 43 of Set 7 | abu zabad
# Processing Record 44 of Set 7 | aswan
# Processing Record 45 of Set 7 | pukhrayan
# Processing Record 46 of Set 7 | cayenne
# Processing Record 47 of Set 7 | birin
# Processing Record 48 of Set 7 | camacha
# Processing Record 49 of Set 7 | yar-sale
# Processing Record 50 of Set 7 | hondo
# Processing Record 1 of Set 8 | castro
# Processing Record 2 of Set 8 | troitsko-pechorsk
# Processing Record 3 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 8 | ahipara
# Processing Record 5 of Set 8 | cabo san lucas
# Processing Record 6 of Set 8 | tuatapere
# Processing Record 7 of Set 8 | vagur
# Processing Record 8 of Set 8 | saint-pierre
# Processing Record 9 of Set 8 | inuvik
# Processing Record 10 of Set 8 | cranbrook
# Processing Record 11 of Set 8 | luang prabang
# Processing Record 12 of Set 8 | soto la marina
# Processing Record 13 of Set 8 | nurota
# Processing Record 14 of Set 8 | goderich
# Processing Record 15 of Set 8 | te anau
# Processing Record 16 of Set 8 | dubti
# Processing Record 17 of Set 8 | abashiri
# Processing Record 18 of Set 8 | tenosique
# Processing Record 19 of Set 8 | anloga
# Processing Record 20 of Set 8 | tommot
# Processing Record 21 of Set 8 | atar
# Processing Record 22 of Set 8 | los llanos de aridane
# Processing Record 23 of Set 8 | moussoro
# Processing Record 24 of Set 8 | baruun-urt
# Processing Record 25 of Set 8 | mpongwe
# Processing Record 26 of Set 8 | aksarka
# Processing Record 27 of Set 8 | nizhniy kuranakh
# Processing Record 28 of Set 8 | igarka
# Processing Record 29 of Set 8 | boa vista
# Processing Record 30 of Set 8 | brownsville
# Processing Record 31 of Set 8 | tuy hoa
# Processing Record 32 of Set 8 | cockburn town
# Processing Record 33 of Set 8 | westlock
# Processing Record 34 of Set 8 | coihaique
# Processing Record 35 of Set 8 | kamskiye polyany
# Processing Record 36 of Set 8 | paka
# Processing Record 37 of Set 8 | san juan
# Processing Record 38 of Set 8 | belmopan
# Processing Record 39 of Set 8 | nuevo progreso
# Processing Record 40 of Set 8 | sochi
# Processing Record 41 of Set 8 | moranbah
# Processing Record 42 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 8 | kamina
# Processing Record 44 of Set 8 | paciran
# Processing Record 45 of Set 8 | tagusao
# Processing Record 46 of Set 8 | felidhoo
# City not found. Skipping...
# Processing Record 47 of Set 8 | pangody
# Processing Record 48 of Set 8 | pareora
# Processing Record 49 of Set 8 | laguna
# Processing Record 50 of Set 8 | georgetown
# Processing Record 1 of Set 9 | zhangye
# Processing Record 2 of Set 9 | achisay
# City not found. Skipping...
# Processing Record 3 of Set 9 | padang
# Processing Record 4 of Set 9 | porto novo
# Processing Record 5 of Set 9 | villazon
# Processing Record 6 of Set 9 | cap malheureux
# Processing Record 7 of Set 9 | landeck
# Processing Record 8 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 9 of Set 9 | nacala
# Processing Record 10 of Set 9 | nisia floresta
# Processing Record 11 of Set 9 | avera
# Processing Record 12 of Set 9 | baykit
# Processing Record 13 of Set 9 | adeje
# Processing Record 14 of Set 9 | fagersta
# Processing Record 15 of Set 9 | gushikawa
# Processing Record 16 of Set 9 | lasa
# Processing Record 17 of Set 9 | linxia
# Processing Record 18 of Set 9 | paamiut
# Processing Record 19 of Set 9 | wajid
# Processing Record 20 of Set 9 | dalvik
# Processing Record 21 of Set 9 | mahanoro
# Processing Record 22 of Set 9 | nchelenge
# Processing Record 23 of Set 9 | kedougou
# Processing Record 24 of Set 9 | sao filipe
# Processing Record 25 of Set 9 | nelson bay
# Processing Record 26 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 9 | hualmay
# Processing Record 28 of Set 9 | boende
# Processing Record 29 of Set 9 | ornskoldsvik
# Processing Record 30 of Set 9 | phuket
# Processing Record 31 of Set 9 | roald
# Processing Record 32 of Set 9 | erzurum
# Processing Record 33 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 34 of Set 9 | surt
# Processing Record 35 of Set 9 | dillon
# Processing Record 36 of Set 9 | vestmannaeyjar
# Processing Record 37 of Set 9 | khotynets
# Processing Record 38 of Set 9 | barcelos
# Processing Record 39 of Set 9 | varhaug
# Processing Record 40 of Set 9 | pashiya
# Processing Record 41 of Set 9 | itaituba
# Processing Record 42 of Set 9 | balingasay
# Processing Record 43 of Set 9 | araouane
# Processing Record 44 of Set 9 | maykain
# City not found. Skipping...
# Processing Record 45 of Set 9 | lata
# Processing Record 46 of Set 9 | blyth
# Processing Record 47 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 9 | milingimbi
# City not found. Skipping...
# Processing Record 49 of Set 9 | beloha
# Processing Record 50 of Set 9 | windham
# Processing Record 1 of Set 10 | kununurra
# Processing Record 2 of Set 10 | mbini
# Processing Record 3 of Set 10 | yarmouth
# Processing Record 4 of Set 10 | nome
# Processing Record 5 of Set 10 | sabha
# Processing Record 6 of Set 10 | moose factory
# Processing Record 7 of Set 10 | wanning
# Processing Record 8 of Set 10 | hambantota
# Processing Record 9 of Set 10 | vila velha
# Processing Record 10 of Set 10 | raga
# Processing Record 11 of Set 10 | awbari
# Processing Record 12 of Set 10 | buchanan
# Processing Record 13 of Set 10 | kedrovyy
# Processing Record 14 of Set 10 | inhambane
# Processing Record 15 of Set 10 | vyazemskiy
# Processing Record 16 of Set 10 | faanui
# Processing Record 17 of Set 10 | grand-santi
# Processing Record 18 of Set 10 | mikkeli
# Processing Record 19 of Set 10 | tiznit
# Processing Record 20 of Set 10 | torit
# Processing Record 21 of Set 10 | masuguru
# Processing Record 22 of Set 10 | kalanguy
# Processing Record 23 of Set 10 | moron
# Processing Record 24 of Set 10 | maltahohe
# Processing Record 25 of Set 10 | maarianhamina
# Processing Record 26 of Set 10 | da nang
# Processing Record 27 of Set 10 | bac lieu
# Processing Record 28 of Set 10 | kahuta
# Processing Record 29 of Set 10 | hailey
# Processing Record 30 of Set 10 | sistranda
# Processing Record 31 of Set 10 | dingle
# Processing Record 32 of Set 10 | hashtrud
# Processing Record 33 of Set 10 | fartanesti
# City not found. Skipping...
# Processing Record 34 of Set 10 | miandrivazo
# Processing Record 35 of Set 10 | los altos
# Processing Record 36 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 37 of Set 10 | aykhal
# Processing Record 38 of Set 10 | astana
# Processing Record 39 of Set 10 | bambanglipuro
# Processing Record 40 of Set 10 | port hedland
# Processing Record 41 of Set 10 | kijang
# Processing Record 42 of Set 10 | sola
# Processing Record 43 of Set 10 | nikolaevo
# Processing Record 44 of Set 10 | cururupu
# Processing Record 45 of Set 10 | balgazyn
# Processing Record 46 of Set 10 | agustin codazzi
# Processing Record 47 of Set 10 | mugur-aksy
# Processing Record 48 of Set 10 | linjiang
# Processing Record 49 of Set 10 | malakal
# Processing Record 50 of Set 10 | bom jesus
# Processing Record 1 of Set 11 | bahia blanca
# Processing Record 2 of Set 11 | shakawe
# Processing Record 3 of Set 11 | nemuro
# Processing Record 4 of Set 11 | gikongoro
# Processing Record 5 of Set 11 | leua
# Processing Record 6 of Set 11 | port-cartier
# Processing Record 7 of Set 11 | brae
# Processing Record 8 of Set 11 | bardiyah
# Processing Record 9 of Set 11 | sfantu gheorghe
# Processing Record 10 of Set 11 | cortez
# Processing Record 11 of Set 11 | turcoaia
# Processing Record 12 of Set 11 | ksenyevka
# City not found. Skipping...
# Processing Record 13 of Set 11 | ketchikan
# Processing Record 14 of Set 11 | osorno
# Processing Record 15 of Set 11 | babati
# Processing Record 16 of Set 11 | palmares
# Processing Record 17 of Set 11 | tamandare
# Processing Record 18 of Set 11 | dukat
# Processing Record 19 of Set 11 | raigarh
# Processing Record 20 of Set 11 | tucurui
# Processing Record 21 of Set 11 | thyboron
# Processing Record 22 of Set 11 | bulawayo
# Processing Record 23 of Set 11 | rio verde de mato grosso
# Processing Record 24 of Set 11 | sur
# Processing Record 25 of Set 11 | batagay-alyta
# Processing Record 26 of Set 11 | sainte-anne-des-monts
# Processing Record 27 of Set 11 | ozernovskiy
# Processing Record 28 of Set 11 | banaue
# Processing Record 29 of Set 11 | oriximina
# Processing Record 30 of Set 11 | agadez
# Processing Record 31 of Set 11 | lakes entrance
# Processing Record 32 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 33 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 34 of Set 11 | khromtau
# Processing Record 35 of Set 11 | sao raimundo das mangabeiras
# Processing Record 36 of Set 11 | srednekolymsk
# Processing Record 37 of Set 11 | eydhafushi
# Processing Record 38 of Set 11 | rongcheng
# Processing Record 39 of Set 11 | banjar
# Processing Record 40 of Set 11 | kathmandu
# Processing Record 41 of Set 11 | mana
# Processing Record 42 of Set 11 | faya
# Processing Record 43 of Set 11 | ca mau
# Processing Record 44 of Set 11 | tulsipur
# Processing Record 45 of Set 11 | komsomolskiy
# Processing Record 46 of Set 11 | hervey bay
# Processing Record 47 of Set 11 | meybod
# Processing Record 48 of Set 11 | ilhabela
# Processing Record 49 of Set 11 | kuching
# Processing Record 50 of Set 11 | iracoubo
# Processing Record 1 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 2 of Set 12 | ankara
# Processing Record 3 of Set 12 | beringovskiy
# Processing Record 4 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 12 | waddan
# Processing Record 6 of Set 12 | chirongui
# Processing Record 7 of Set 12 | kavieng
# Processing Record 8 of Set 12 | hearst
# Processing Record 9 of Set 12 | bataipora
# Processing Record 10 of Set 12 | requena
# Processing Record 11 of Set 12 | yumen
# Processing Record 12 of Set 12 | nago
# Processing Record 13 of Set 12 | coos bay
# Processing Record 14 of Set 12 | oksovskiy
# Processing Record 15 of Set 12 | qandala
# Processing Record 16 of Set 12 | thayetmyo
# Processing Record 17 of Set 12 | oksfjord
# Processing Record 18 of Set 12 | langsa
# Processing Record 19 of Set 12 | portland
# Processing Record 20 of Set 12 | yumbing
# Processing Record 21 of Set 12 | hanna
# Processing Record 22 of Set 12 | chitrakonda
# Processing Record 23 of Set 12 | timmins
# Processing Record 24 of Set 12 | tarakan
# Processing Record 25 of Set 12 | orange cove
# Processing Record 26 of Set 12 | esmeraldas
# Processing Record 27 of Set 12 | takoradi
# Processing Record 28 of Set 12 | nechi
# Processing Record 29 of Set 12 | ternate
# Processing Record 30 of Set 12 | kupang
# Processing Record 31 of Set 12 | broken hill
# Processing Record 32 of Set 12 | severobaykalsk
# Processing Record 33 of Set 12 | hasilpur
# Processing Record 34 of Set 12 | talnakh
# Processing Record 35 of Set 12 | kavaratti
# Processing Record 36 of Set 12 | meadow lake
# Processing Record 37 of Set 12 | alta floresta
# Processing Record 38 of Set 12 | maragogi
# Processing Record 39 of Set 12 | marsh harbour
# Processing Record 40 of Set 12 | hamilton
# Processing Record 41 of Set 12 | alpena
# Processing Record 42 of Set 12 | burley
# Processing Record 43 of Set 12 | marau
# Processing Record 44 of Set 12 | oistins
# Processing Record 45 of Set 12 | pangnirtung
# Processing Record 46 of Set 12 | voi
# Processing Record 47 of Set 12 | yerbogachen
# Processing Record 48 of Set 12 | sarkand
# Processing Record 49 of Set 12 | vila
# Processing Record 50 of Set 12 | kiruna
# Processing Record 1 of Set 13 | vardo
# Processing Record 2 of Set 13 | olafsvik
# Processing Record 3 of Set 13 | tupik
# Processing Record 4 of Set 13 | freeport
# Processing Record 5 of Set 13 | pontianak
# Processing Record 6 of Set 13 | bayan
# Processing Record 7 of Set 13 | maneromango
# Processing Record 8 of Set 13 | shalinskoye
# Processing Record 9 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 10 of Set 13 | dicabisagan
# Processing Record 11 of Set 13 | namwala
# Processing Record 12 of Set 13 | kapuskasing
# Processing Record 13 of Set 13 | tual
# Processing Record 14 of Set 13 | nushki
# Processing Record 15 of Set 13 | kanadey
# Processing Record 16 of Set 13 | paucartambo
# City not found. Skipping...
# Processing Record 17 of Set 13 | gull lake
# Processing Record 18 of Set 13 | keti bandar
# Processing Record 19 of Set 13 | charters towers
# Processing Record 20 of Set 13 | vostok
# Processing Record 21 of Set 13 | covington
# Processing Record 22 of Set 13 | ust-omchug
# Processing Record 23 of Set 13 | prince rupert
# Processing Record 24 of Set 13 | iwanai
# Processing Record 25 of Set 13 | namibe
# Processing Record 26 of Set 13 | roebourne
# Processing Record 27 of Set 13 | solton
# Processing Record 28 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 13 | san cristobal
# Processing Record 30 of Set 13 | sussex
# Processing Record 31 of Set 13 | natal
# Processing Record 32 of Set 13 | kahului
# Processing Record 33 of Set 13 | kungurtug
# Processing Record 34 of Set 13 | amstetten
# Processing Record 35 of Set 13 | erdemli
# Processing Record 36 of Set 13 | reconquista
# Processing Record 37 of Set 13 | dunmore town
# Processing Record 38 of Set 13 | northam
# Processing Record 39 of Set 13 | empalme
# Processing Record 40 of Set 13 | alibag
# Processing Record 41 of Set 13 | quatre cocos
# Processing Record 42 of Set 13 | shingu
# Processing Record 43 of Set 13 | la palma
# Processing Record 44 of Set 13 | poya
# Processing Record 45 of Set 13 | cordoba
# Processing Record 46 of Set 13 | cairns
# Processing Record 47 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 48 of Set 13 | suzun
# Processing Record 49 of Set 13 | gold coast
# Processing Record 50 of Set 13 | nouadhibou
# Processing Record 1 of Set 14 | kachug
# Processing Record 2 of Set 14 | duvan
# Processing Record 3 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 4 of Set 14 | vangaindrano
# Processing Record 5 of Set 14 | zhanaozen
# Processing Record 6 of Set 14 | batemans bay
# Processing Record 7 of Set 14 | kamarion
# Processing Record 8 of Set 14 | ampanihy
# Processing Record 9 of Set 14 | diglur
# Processing Record 10 of Set 14 | khorramshahr
# Processing Record 11 of Set 14 | tongsa
# City not found. Skipping...
# Processing Record 12 of Set 14 | mangaratiba
# Processing Record 13 of Set 14 | nsanje
# Processing Record 14 of Set 14 | havoysund
# Processing Record 15 of Set 14 | burnie
# Processing Record 16 of Set 14 | kinsale
# Processing Record 17 of Set 14 | callaway
# Processing Record 18 of Set 14 | monrovia
# Processing Record 19 of Set 14 | myanaung
# Processing Record 20 of Set 14 | yakeshi
# Processing Record 21 of Set 14 | doha
# Processing Record 22 of Set 14 | puerto madero
# Processing Record 23 of Set 14 | puerto quijarro
# Processing Record 24 of Set 14 | beian
# Processing Record 25 of Set 14 | minot
# Processing Record 26 of Set 14 | auxerre
# Processing Record 27 of Set 14 | plouzane
# Processing Record 28 of Set 14 | maniitsoq
# Processing Record 29 of Set 14 | mareeba
# Processing Record 30 of Set 14 | antalaha
# Processing Record 31 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 14 | turiacu
# Processing Record 33 of Set 14 | lodja
# Processing Record 34 of Set 14 | axim
# Processing Record 35 of Set 14 | napasar
# Processing Record 36 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 38 of Set 14 | opuwo
# Processing Record 39 of Set 14 | mercedes
# Processing Record 40 of Set 14 | zastron
# Processing Record 41 of Set 14 | auki
# Processing Record 42 of Set 14 | ucluelet
# Processing Record 43 of Set 14 | rio hato
# Processing Record 44 of Set 14 | west des moines
# Processing Record 45 of Set 14 | igunga
# Processing Record 46 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 14 | gonzalez
# Processing Record 48 of Set 14 | tura
# Processing Record 49 of Set 14 | hami
# Processing Record 50 of Set 14 | nadym
# Processing Record 1 of Set 15 | turbat
# Processing Record 2 of Set 15 | nyurba
# Processing Record 3 of Set 15 | hattiesburg
# Processing Record 4 of Set 15 | abu samrah
# Processing Record 5 of Set 15 | tadine
# Processing Record 6 of Set 15 | sikeston
# Processing Record 7 of Set 15 | lalmohan
# Processing Record 8 of Set 15 | waitati
# Processing Record 9 of Set 15 | college
# Processing Record 10 of Set 15 | batticaloa
# Processing Record 11 of Set 15 | maldonado
# Processing Record 12 of Set 15 | wajima
# Processing Record 13 of Set 15 | campbellton
# Processing Record 14 of Set 15 | rajmahal
# Processing Record 15 of Set 15 | santa isabel do rio negro
# Processing Record 16 of Set 15 | lesnoy
# Processing Record 17 of Set 15 | turukhansk
# Processing Record 18 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 19 of Set 15 | lahij
# Processing Record 20 of Set 15 | ambon
# Processing Record 21 of Set 15 | santa rosa
# Processing Record 22 of Set 15 | derzhavinsk
# Processing Record 23 of Set 15 | haines junction
# Processing Record 24 of Set 15 | klaksvik
# Processing Record 25 of Set 15 | katsuura
# Processing Record 26 of Set 15 | villarrica
# Processing Record 27 of Set 15 | clinton
# Processing Record 28 of Set 15 | sawakin
# Processing Record 29 of Set 15 | fort nelson
# Processing Record 30 of Set 15 | gayny
# Processing Record 31 of Set 15 | bria
# Processing Record 32 of Set 15 | podbelsk
# City not found. Skipping...
# Processing Record 33 of Set 15 | mayo
# Processing Record 34 of Set 15 | qasigiannguit
# Processing Record 35 of Set 15 | zhicheng
# Processing Record 36 of Set 15 | syracuse
# Processing Record 37 of Set 15 | lazaro cardenas
# Processing Record 38 of Set 15 | diamantino
# Processing Record 39 of Set 15 | tugolesskiy bor
# Processing Record 40 of Set 15 | dera bugti
# Processing Record 41 of Set 15 | restrepo
# Processing Record 42 of Set 15 | coolum beach
# Processing Record 43 of Set 15 | xining
# Processing Record 44 of Set 15 | iquique
# Processing Record 45 of Set 15 | mogadishu
# Processing Record 46 of Set 15 | brandenburg
# Processing Record 47 of Set 15 | santa isabel
# Processing Record 48 of Set 15 | aden
# Processing Record 49 of Set 15 | port maria
# Processing Record 50 of Set 15 | tuensang
# Processing Record 1 of Set 16 | ouesso
# Processing Record 2 of Set 16 | talaya
# Processing Record 3 of Set 16 | kendari
# Processing Record 4 of Set 16 | saurimo
# Processing Record 5 of Set 16 | general pico
# Processing Record 6 of Set 16 | mount gambier
# Processing Record 7 of Set 16 | tukrah
# Processing Record 8 of Set 16 | coahuayana
# Processing Record 9 of Set 16 | jishou
# Processing Record 10 of Set 16 | santa cruz
# Processing Record 11 of Set 16 | kurumkan
# Processing Record 12 of Set 16 | samara
# Processing Record 13 of Set 16 | berlevag
# Processing Record 14 of Set 16 | nantucket
# Processing Record 15 of Set 16 | liwale
# Processing Record 16 of Set 16 | kamaishi
# Processing Record 17 of Set 16 | morrope
# Processing Record 18 of Set 16 | barkly west
# Processing Record 19 of Set 16 | hadimkoy
# City not found. Skipping...
# -----------------------------------------
# Data Retrieval Complete
# -----------------------------------------

# %%
len(city_data)

# %%
#Add the data to a new DataFrame.
city_weather_df = pd.DataFrame(city_data)
city_weather_df.head()

# %%
output_file_path = "/Users/ttuser/Downloads/Module6/WeatherPy_Database.csv"
city_weather_df.to_csv(output_file_path, index=False)
