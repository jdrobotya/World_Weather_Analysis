# %%
# Import dependencies
import pandas as pd
import numpy as np
import sys
from config import weather_api_key
import requests

# %%
#Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
#Get the nearest city using the citipy module.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 721

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval         ")
print("---------------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
        # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        
        
       
        # Append the city information into the city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})
        
    # If an error is experience, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------------------")
print("Data Retrieval Complete            ")
print("-----------------------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------------------
# Processing Record 1 of Set 1 | port elizabeth
# Processing Record 2 of Set 1 | teseney
# Processing Record 3 of Set 1 | saint-joseph
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | mount isa
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | dikson
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | sosnovskiy
# City not found. Skipping...
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | vila velha
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | boueni
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | taoudenni
# Processing Record 23 of Set 1 | grand gaube
# Processing Record 24 of Set 1 | trelew
# Processing Record 25 of Set 1 | padang
# Processing Record 26 of Set 1 | atasu
# Processing Record 27 of Set 1 | matadi
# Processing Record 28 of Set 1 | bom jesus
# Processing Record 29 of Set 1 | sabha
# Processing Record 30 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 1 | salinopolis
# Processing Record 33 of Set 1 | east london
# Processing Record 34 of Set 1 | arlit
# Processing Record 35 of Set 1 | bulgan
# Processing Record 36 of Set 1 | lorengau
# Processing Record 37 of Set 1 | bandarbeyla
# Processing Record 38 of Set 1 | kavieng
# Processing Record 39 of Set 1 | nam tha
# City not found. Skipping...
# Processing Record 40 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 41 of Set 1 | brookhaven
# Processing Record 42 of Set 1 | yulara
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | porto nacional
# Processing Record 45 of Set 1 | cabo san lucas
# Processing Record 46 of Set 1 | pangody
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | grindavik
# Processing Record 49 of Set 1 | khatanga
# Processing Record 50 of Set 1 | klaksvik
# Processing Record 1 of Set 2 | port blair
# Processing Record 2 of Set 2 | kruisfontein
# Processing Record 3 of Set 2 | katobu
# Processing Record 4 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 7 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 2 | lewiston
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | gelnhausen
# Processing Record 11 of Set 2 | kibala
# Processing Record 12 of Set 2 | bengkulu
# Processing Record 13 of Set 2 | virginia beach
# Processing Record 14 of Set 2 | lazaro cardenas
# Processing Record 15 of Set 2 | esperance
# Processing Record 16 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 2 | fortuna
# Processing Record 18 of Set 2 | hithadhoo
# Processing Record 19 of Set 2 | guerrero negro
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 2 | hobart
# Processing Record 24 of Set 2 | kaitangata
# Processing Record 25 of Set 2 | alyangula
# Processing Record 26 of Set 2 | babu
# Processing Record 27 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 2 | pevek
# Processing Record 29 of Set 2 | bethel
# Processing Record 30 of Set 2 | havelock
# Processing Record 31 of Set 2 | mahebourg
# Processing Record 32 of Set 2 | bluff
# Processing Record 33 of Set 2 | adelaide
# Processing Record 34 of Set 2 | albany
# Processing Record 35 of Set 2 | pergamino
# Processing Record 36 of Set 2 | emerald
# Processing Record 37 of Set 2 | neyshabur
# Processing Record 38 of Set 2 | mwinilunga
# Processing Record 39 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 2 | lagoa
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | atuona
# Processing Record 43 of Set 2 | santa barbara
# Processing Record 44 of Set 2 | plesetsk
# Processing Record 45 of Set 2 | upernavik
# Processing Record 46 of Set 2 | tasiilaq
# Processing Record 47 of Set 2 | belen
# Processing Record 48 of Set 2 | prince rupert
# Processing Record 49 of Set 2 | port alfred
# Processing Record 50 of Set 2 | chokurdakh
# Processing Record 1 of Set 3 | sechelt
# Processing Record 2 of Set 3 | iqaluit
# Processing Record 3 of Set 3 | asfi
# Processing Record 4 of Set 3 | vardo
# Processing Record 5 of Set 3 | churachandpur
# Processing Record 6 of Set 3 | champerico
# Processing Record 7 of Set 3 | sao filipe
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | kahului
# Processing Record 10 of Set 3 | rio verde de mato grosso
# Processing Record 11 of Set 3 | morococha
# Processing Record 12 of Set 3 | emet
# Processing Record 13 of Set 3 | castro
# Processing Record 14 of Set 3 | rafai
# Processing Record 15 of Set 3 | lenoir city
# Processing Record 16 of Set 3 | saint-philippe
# Processing Record 17 of Set 3 | kapaa
# Processing Record 18 of Set 3 | kloulklubed
# Processing Record 19 of Set 3 | bonthe
# Processing Record 20 of Set 3 | hilo
# Processing Record 21 of Set 3 | busselton
# Processing Record 22 of Set 3 | totma
# Processing Record 23 of Set 3 | sao joao da barra
# Processing Record 24 of Set 3 | zeya
# Processing Record 25 of Set 3 | odesskoye
# Processing Record 26 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 3 | puerto suarez
# Processing Record 28 of Set 3 | ahipara
# Processing Record 29 of Set 3 | wanning
# Processing Record 30 of Set 3 | victoria
# Processing Record 31 of Set 3 | airai
# Processing Record 32 of Set 3 | nome
# Processing Record 33 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 3 | riyadh
# Processing Record 35 of Set 3 | katsuura
# Processing Record 36 of Set 3 | bowen
# Processing Record 37 of Set 3 | longyearbyen
# Processing Record 38 of Set 3 | barrow
# Processing Record 39 of Set 3 | ulladulla
# Processing Record 40 of Set 3 | cape town
# Processing Record 41 of Set 3 | sidney
# Processing Record 42 of Set 3 | puerto carreno
# Processing Record 43 of Set 3 | jumla
# Processing Record 44 of Set 3 | port hardy
# Processing Record 45 of Set 3 | khorramshahr
# Processing Record 46 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 3 | shaoyang
# Processing Record 48 of Set 3 | biu
# Processing Record 49 of Set 3 | cerrito
# Processing Record 50 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 4 | vaini
# Processing Record 2 of Set 4 | fairbanks
# Processing Record 3 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 4 | lebu
# Processing Record 5 of Set 4 | provideniya
# Processing Record 6 of Set 4 | chicama
# Processing Record 7 of Set 4 | ferai
# City not found. Skipping...
# Processing Record 8 of Set 4 | ardrishaig
# Processing Record 9 of Set 4 | fare
# Processing Record 10 of Set 4 | tuktoyaktuk
# Processing Record 11 of Set 4 | ahuimanu
# Processing Record 12 of Set 4 | kibaya
# Processing Record 13 of Set 4 | do gonbadan
# Processing Record 14 of Set 4 | mar del plata
# Processing Record 15 of Set 4 | new norfolk
# Processing Record 16 of Set 4 | bambous virieux
# Processing Record 17 of Set 4 | haines junction
# Processing Record 18 of Set 4 | kolosovka
# Processing Record 19 of Set 4 | saint george
# Processing Record 20 of Set 4 | severo-kurilsk
# Processing Record 21 of Set 4 | adre
# Processing Record 22 of Set 4 | loa janan
# Processing Record 23 of Set 4 | moroni
# Processing Record 24 of Set 4 | cordoba
# Processing Record 25 of Set 4 | kirando
# Processing Record 26 of Set 4 | schuttorf
# Processing Record 27 of Set 4 | monte alegre
# Processing Record 28 of Set 4 | carnarvon
# Processing Record 29 of Set 4 | katangli
# Processing Record 30 of Set 4 | umm lajj
# Processing Record 31 of Set 4 | valuyki
# Processing Record 32 of Set 4 | acapulco
# Processing Record 33 of Set 4 | baisha
# Processing Record 34 of Set 4 | urucara
# Processing Record 35 of Set 4 | otorohanga
# Processing Record 36 of Set 4 | benalla
# Processing Record 37 of Set 4 | orsha
# Processing Record 38 of Set 4 | konevo
# Processing Record 39 of Set 4 | mattawa
# Processing Record 40 of Set 4 | shimoda
# Processing Record 41 of Set 4 | kralendijk
# Processing Record 42 of Set 4 | hovd
# Processing Record 43 of Set 4 | sergach
# Processing Record 44 of Set 4 | leningradskiy
# Processing Record 45 of Set 4 | college
# Processing Record 46 of Set 4 | oktyabrskiy
# Processing Record 47 of Set 4 | carutapera
# Processing Record 48 of Set 4 | whyalla
# Processing Record 49 of Set 4 | antofagasta
# Processing Record 50 of Set 4 | marsh harbour
# Processing Record 1 of Set 5 | hun
# Processing Record 2 of Set 5 | lata
# Processing Record 3 of Set 5 | katha
# City not found. Skipping...
# Processing Record 4 of Set 5 | namatanai
# Processing Record 5 of Set 5 | zhangye
# Processing Record 6 of Set 5 | chuy
# Processing Record 7 of Set 5 | saskylakh
# Processing Record 8 of Set 5 | tura
# Processing Record 9 of Set 5 | lasa
# Processing Record 10 of Set 5 | healdsburg
# Processing Record 11 of Set 5 | lushoto
# Processing Record 12 of Set 5 | cayenne
# Processing Record 13 of Set 5 | mirpur sakro
# Processing Record 14 of Set 5 | geraldton
# Processing Record 15 of Set 5 | manono
# Processing Record 16 of Set 5 | acarau
# Processing Record 17 of Set 5 | kununurra
# Processing Record 18 of Set 5 | caravelas
# Processing Record 19 of Set 5 | khandagayty
# Processing Record 20 of Set 5 | salalah
# Processing Record 21 of Set 5 | margate
# Processing Record 22 of Set 5 | itarema
# Processing Record 23 of Set 5 | la ronge
# Processing Record 24 of Set 5 | georgetown
# Processing Record 25 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 5 | przhevalskoye
# Processing Record 27 of Set 5 | nhulunbuy
# Processing Record 28 of Set 5 | whitehorse
# Processing Record 29 of Set 5 | te anau
# Processing Record 30 of Set 5 | barao de melgaco
# Processing Record 31 of Set 5 | baykit
# Processing Record 32 of Set 5 | faanui
# Processing Record 33 of Set 5 | panzhihua
# Processing Record 34 of Set 5 | anadyr
# Processing Record 35 of Set 5 | alice springs
# Processing Record 36 of Set 5 | cherskiy
# Processing Record 37 of Set 5 | hasaki
# Processing Record 38 of Set 5 | dunedin
# Processing Record 39 of Set 5 | takaka
# Processing Record 40 of Set 5 | lompoc
# Processing Record 41 of Set 5 | port moresby
# Processing Record 42 of Set 5 | coquimbo
# Processing Record 43 of Set 5 | praia da vitoria
# Processing Record 44 of Set 5 | ponta do sol
# Processing Record 45 of Set 5 | nabha
# Processing Record 46 of Set 5 | ust-omchug
# Processing Record 47 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 48 of Set 5 | north bend
# Processing Record 49 of Set 5 | korba
# Processing Record 50 of Set 5 | kailua
# Processing Record 1 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 2 of Set 6 | broadstairs
# Processing Record 3 of Set 6 | labuhan
# Processing Record 4 of Set 6 | husavik
# Processing Record 5 of Set 6 | beloha
# Processing Record 6 of Set 6 | vostok
# Processing Record 7 of Set 6 | constitucion
# Processing Record 8 of Set 6 | malaryta
# Processing Record 9 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 6 | sorong
# Processing Record 11 of Set 6 | ilulissat
# Processing Record 12 of Set 6 | gigmoto
# Processing Record 13 of Set 6 | zarubino
# Processing Record 14 of Set 6 | southbridge
# Processing Record 15 of Set 6 | qaanaaq
# Processing Record 16 of Set 6 | boyolangu
# Processing Record 17 of Set 6 | savannah bight
# Processing Record 18 of Set 6 | ancud
# Processing Record 19 of Set 6 | norman wells
# Processing Record 20 of Set 6 | vesyegonsk
# Processing Record 21 of Set 6 | calbuco
# Processing Record 22 of Set 6 | katherine
# Processing Record 23 of Set 6 | stornoway
# Processing Record 24 of Set 6 | poya
# Processing Record 25 of Set 6 | grahamstown
# Processing Record 26 of Set 6 | broome
# Processing Record 27 of Set 6 | vladeni
# Processing Record 28 of Set 6 | yinchuan
# Processing Record 29 of Set 6 | artyom
# Processing Record 30 of Set 6 | eitorf
# Processing Record 31 of Set 6 | palmas bellas
# Processing Record 32 of Set 6 | ostrovnoy
# Processing Record 33 of Set 6 | gimli
# Processing Record 34 of Set 6 | kristiinankaupunki
# Processing Record 35 of Set 6 | ottawa
# Processing Record 36 of Set 6 | sitka
# Processing Record 37 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 38 of Set 6 | freeport
# Processing Record 39 of Set 6 | tiksi
# Processing Record 40 of Set 6 | hinton
# Processing Record 41 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 42 of Set 6 | nishihara
# Processing Record 43 of Set 6 | sobolevo
# Processing Record 44 of Set 6 | saint-pierre
# Processing Record 45 of Set 6 | basco
# Processing Record 46 of Set 6 | christchurch
# Processing Record 47 of Set 6 | avera
# Processing Record 48 of Set 6 | petatlan
# Processing Record 49 of Set 6 | nefteyugansk
# Processing Record 50 of Set 6 | san jose
# Processing Record 1 of Set 7 | bathsheba
# Processing Record 2 of Set 7 | long xuyen
# Processing Record 3 of Set 7 | port lincoln
# Processing Record 4 of Set 7 | raahe
# Processing Record 5 of Set 7 | codrington
# Processing Record 6 of Set 7 | cap malheureux
# Processing Record 7 of Set 7 | platteville
# Processing Record 8 of Set 7 | naryan-mar
# Processing Record 9 of Set 7 | kodiak
# Processing Record 10 of Set 7 | piterka
# Processing Record 11 of Set 7 | sioux lookout
# Processing Record 12 of Set 7 | ballina
# Processing Record 13 of Set 7 | presidente olegario
# Processing Record 14 of Set 7 | tanggu
# Processing Record 15 of Set 7 | khani
# Processing Record 16 of Set 7 | lavrentiya
# Processing Record 17 of Set 7 | bundaberg
# Processing Record 18 of Set 7 | le port
# Processing Record 19 of Set 7 | biak
# Processing Record 20 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 21 of Set 7 | canutama
# Processing Record 22 of Set 7 | narsaq
# Processing Record 23 of Set 7 | henties bay
# Processing Record 24 of Set 7 | west lorne
# Processing Record 25 of Set 7 | kiunga
# Processing Record 26 of Set 7 | asau
# Processing Record 27 of Set 7 | berdigestyakh
# Processing Record 28 of Set 7 | kargil
# Processing Record 29 of Set 7 | stromness
# Processing Record 30 of Set 7 | kilindoni
# Processing Record 31 of Set 7 | knysna
# Processing Record 32 of Set 7 | vao
# Processing Record 33 of Set 7 | hervey bay
# Processing Record 34 of Set 7 | muravlenko
# Processing Record 35 of Set 7 | deputatskiy
# Processing Record 36 of Set 7 | la concordia
# Processing Record 37 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 7 | ikalamavony
# Processing Record 39 of Set 7 | laguna
# Processing Record 40 of Set 7 | hamilton
# Processing Record 41 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 42 of Set 7 | doha
# Processing Record 43 of Set 7 | isoka
# Processing Record 44 of Set 7 | isangel
# Processing Record 45 of Set 7 | bara
# Processing Record 46 of Set 7 | bosaso
# Processing Record 47 of Set 7 | luderitz
# Processing Record 48 of Set 7 | fort nelson
# Processing Record 49 of Set 7 | tukrah
# Processing Record 50 of Set 7 | kalemie
# Processing Record 1 of Set 8 | aleksandrovskiy zavod
# Processing Record 2 of Set 8 | guapiacu
# Processing Record 3 of Set 8 | abu samrah
# Processing Record 4 of Set 8 | kangaatsiaq
# Processing Record 5 of Set 8 | les escoumins
# Processing Record 6 of Set 8 | peniche
# Processing Record 7 of Set 8 | agadir
# Processing Record 8 of Set 8 | amuntai
# Processing Record 9 of Set 8 | chara
# Processing Record 10 of Set 8 | mount gambier
# Processing Record 11 of Set 8 | la palma
# Processing Record 12 of Set 8 | hirara
# Processing Record 13 of Set 8 | beisfjord
# Processing Record 14 of Set 8 | kieta
# Processing Record 15 of Set 8 | paita
# Processing Record 16 of Set 8 | ambunti
# Processing Record 17 of Set 8 | clyde river
# Processing Record 18 of Set 8 | san angelo
# Processing Record 19 of Set 8 | halifax
# Processing Record 20 of Set 8 | brigantine
# Processing Record 21 of Set 8 | yar-sale
# Processing Record 22 of Set 8 | kroya
# Processing Record 23 of Set 8 | gayeri
# Processing Record 24 of Set 8 | chifeng
# Processing Record 25 of Set 8 | matara
# Processing Record 26 of Set 8 | salacgriva
# Processing Record 27 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 8 | mapiripan
# Processing Record 29 of Set 8 | palmer
# Processing Record 30 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 31 of Set 8 | jablah
# Processing Record 32 of Set 8 | lamar
# Processing Record 33 of Set 8 | wana
# Processing Record 34 of Set 8 | ikom
# Processing Record 35 of Set 8 | yumen
# Processing Record 36 of Set 8 | mankono
# Processing Record 37 of Set 8 | srednekolymsk
# Processing Record 38 of Set 8 | juneau
# Processing Record 39 of Set 8 | fukue
# Processing Record 40 of Set 8 | okhotsk
# Processing Record 41 of Set 8 | tarakan
# Processing Record 42 of Set 8 | sibolga
# Processing Record 43 of Set 8 | vestmanna
# Processing Record 44 of Set 8 | nouadhibou
# Processing Record 45 of Set 8 | sistranda
# Processing Record 46 of Set 8 | victor harbor
# Processing Record 47 of Set 8 | noshiro
# Processing Record 48 of Set 8 | verkh-suetka
# Processing Record 49 of Set 8 | semirom
# Processing Record 50 of Set 8 | vila franca do campo
# Processing Record 1 of Set 9 | singkang
# Processing Record 2 of Set 9 | belmonte
# Processing Record 3 of Set 9 | san vicente
# Processing Record 4 of Set 9 | puerto escondido
# Processing Record 5 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 6 of Set 9 | phan thiet
# Processing Record 7 of Set 9 | walvis bay
# Processing Record 8 of Set 9 | san juan
# Processing Record 9 of Set 9 | mushie
# Processing Record 10 of Set 9 | tutoia
# Processing Record 11 of Set 9 | maniitsoq
# Processing Record 12 of Set 9 | dingle
# Processing Record 13 of Set 9 | matsanga
# City not found. Skipping...
# Processing Record 14 of Set 9 | mayo
# Processing Record 15 of Set 9 | san cataldo
# Processing Record 16 of Set 9 | burgos
# Processing Record 17 of Set 9 | poum
# Processing Record 18 of Set 9 | torbay
# Processing Record 19 of Set 9 | devadanapatti
# City not found. Skipping...
# Processing Record 20 of Set 9 | thunder bay
# Processing Record 21 of Set 9 | olafsvik
# Processing Record 22 of Set 9 | serta
# Processing Record 23 of Set 9 | solnechnyy
# Processing Record 24 of Set 9 | road town
# Processing Record 25 of Set 9 | svetlogorsk
# Processing Record 26 of Set 9 | east islip
# Processing Record 27 of Set 9 | ambilobe
# Processing Record 28 of Set 9 | elizabeth city
# Processing Record 29 of Set 9 | touros
# Processing Record 30 of Set 9 | freetown
# Processing Record 31 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 9 | cairns
# Processing Record 33 of Set 9 | murgab
# Processing Record 34 of Set 9 | faya
# Processing Record 35 of Set 9 | mabaruma
# Processing Record 36 of Set 9 | lodja
# Processing Record 37 of Set 9 | roma
# Processing Record 38 of Set 9 | shevchenkove
# Processing Record 39 of Set 9 | saldanha
# Processing Record 40 of Set 9 | juan aldama
# Processing Record 41 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 42 of Set 9 | the valley
# Processing Record 43 of Set 9 | paamiut
# Processing Record 44 of Set 9 | alta floresta
# Processing Record 45 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 9 | borogontsy
# Processing Record 47 of Set 9 | chapais
# Processing Record 48 of Set 9 | yamoto
# Processing Record 49 of Set 9 | tlahualilo
# City not found. Skipping...
# Processing Record 50 of Set 9 | waw
# Processing Record 1 of Set 10 | rabak
# Processing Record 2 of Set 10 | jinchang
# Processing Record 3 of Set 10 | pisco
# Processing Record 4 of Set 10 | sangar
# Processing Record 5 of Set 10 | arrecife
# Processing Record 6 of Set 10 | kathmandu
# Processing Record 7 of Set 10 | tuatapere
# Processing Record 8 of Set 10 | yarmouth
# Processing Record 9 of Set 10 | kamenka
# Processing Record 10 of Set 10 | shihezi
# Processing Record 11 of Set 10 | comodoro rivadavia
# Processing Record 12 of Set 10 | korla
# Processing Record 13 of Set 10 | yerbogachen
# Processing Record 14 of Set 10 | chumikan
# Processing Record 15 of Set 10 | fuerte
# Processing Record 16 of Set 10 | osoyoos
# Processing Record 17 of Set 10 | littlehampton
# Processing Record 18 of Set 10 | tulun
# Processing Record 19 of Set 10 | zolotinka
# City not found. Skipping...
# Processing Record 20 of Set 10 | liverpool
# Processing Record 21 of Set 10 | joigny
# Processing Record 22 of Set 10 | high rock
# Processing Record 23 of Set 10 | port hedland
# Processing Record 24 of Set 10 | greymouth
# Processing Record 25 of Set 10 | gornopravdinsk
# Processing Record 26 of Set 10 | maltahohe
# Processing Record 27 of Set 10 | ksenyevka
# City not found. Skipping...
# Processing Record 28 of Set 10 | sola
# Processing Record 29 of Set 10 | kusti
# Processing Record 30 of Set 10 | alamosa
# Processing Record 31 of Set 10 | gobindpur
# Processing Record 32 of Set 10 | brenham
# Processing Record 33 of Set 10 | malmesbury
# Processing Record 34 of Set 10 | cusuna
# Processing Record 35 of Set 10 | araouane
# Processing Record 36 of Set 10 | axim
# Processing Record 37 of Set 10 | westport
# Processing Record 38 of Set 10 | limoeiro de anadia
# Processing Record 39 of Set 10 | hambantota
# Processing Record 40 of Set 10 | half moon bay
# Processing Record 41 of Set 10 | pontianak
# Processing Record 42 of Set 10 | nueva loja
# Processing Record 43 of Set 10 | talnakh
# Processing Record 44 of Set 10 | pingliang
# Processing Record 45 of Set 10 | harper
# Processing Record 46 of Set 10 | neulengbach
# Processing Record 47 of Set 10 | bako
# Processing Record 48 of Set 10 | eyl
# Processing Record 49 of Set 10 | san cristobal
# Processing Record 50 of Set 10 | baiyin
# Processing Record 1 of Set 11 | kavaratti
# Processing Record 2 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 11 | roald
# Processing Record 4 of Set 11 | mayskiy
# Processing Record 5 of Set 11 | okha
# Processing Record 6 of Set 11 | tougue
# Processing Record 7 of Set 11 | petauke
# Processing Record 8 of Set 11 | les cayes
# Processing Record 9 of Set 11 | glenluce
# Processing Record 10 of Set 11 | amga
# Processing Record 11 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 12 of Set 11 | kodinsk
# Processing Record 13 of Set 11 | aklavik
# Processing Record 14 of Set 11 | xadani
# City not found. Skipping...
# Processing Record 15 of Set 11 | cidreira
# Processing Record 16 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 11 | bonavista
# Processing Record 18 of Set 11 | yankton
# Processing Record 19 of Set 11 | ondjiva
# Processing Record 20 of Set 11 | ubatuba
# Processing Record 21 of Set 11 | kyabe
# Processing Record 22 of Set 11 | fort dodge
# Processing Record 23 of Set 11 | kefalos
# Processing Record 24 of Set 11 | serowe
# Processing Record 25 of Set 11 | kota
# Processing Record 26 of Set 11 | simbahan
# Processing Record 27 of Set 11 | mezen
# Processing Record 28 of Set 11 | bereznik
# Processing Record 29 of Set 11 | baghdad
# Processing Record 30 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 31 of Set 11 | dourados
# Processing Record 32 of Set 11 | kanniyakumari
# Processing Record 33 of Set 11 | severnoye
# Processing Record 34 of Set 11 | aswan
# Processing Record 35 of Set 11 | wangdiphodrang
# City not found. Skipping...
# Processing Record 36 of Set 11 | muzhi
# Processing Record 37 of Set 11 | rajgurunagar
# Processing Record 38 of Set 11 | uarini
# Processing Record 39 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 11 | lae
# Processing Record 41 of Set 11 | necochea
# Processing Record 42 of Set 11 | hastings
# Processing Record 43 of Set 11 | bay roberts
# Processing Record 44 of Set 11 | tonekabon
# Processing Record 45 of Set 11 | bilibino
# Processing Record 46 of Set 11 | samarai
# Processing Record 47 of Set 11 | lagunas
# Processing Record 48 of Set 11 | aripuana
# Processing Record 49 of Set 11 | los llanos de aridane
# Processing Record 50 of Set 11 | guiratinga
# Processing Record 1 of Set 12 | chernyshevskiy
# Processing Record 2 of Set 12 | bhuj
# Processing Record 3 of Set 12 | saryg-sep
# Processing Record 4 of Set 12 | bose
# Processing Record 5 of Set 12 | saint anthony
# Processing Record 6 of Set 12 | camacha
# Processing Record 7 of Set 12 | nuuk
# Processing Record 8 of Set 12 | ishigaki
# Processing Record 9 of Set 12 | rawson
# Processing Record 10 of Set 12 | quesnel
# Processing Record 11 of Set 12 | swan hill
# Processing Record 12 of Set 12 | goderich
# Processing Record 13 of Set 12 | pitimbu
# Processing Record 14 of Set 12 | ahar
# Processing Record 15 of Set 12 | izumo
# Processing Record 16 of Set 12 | anchorage
# Processing Record 17 of Set 12 | la asuncion
# Processing Record 18 of Set 12 | dakar
# Processing Record 19 of Set 12 | zhezkazgan
# Processing Record 20 of Set 12 | palmeira
# Processing Record 21 of Set 12 | lypnyazhka
# Processing Record 22 of Set 12 | shellbrook
# Processing Record 23 of Set 12 | nanortalik
# Processing Record 24 of Set 12 | porto uniao
# Processing Record 25 of Set 12 | ambon
# Processing Record 26 of Set 12 | kinsale
# Processing Record 27 of Set 12 | nakamura
# Processing Record 28 of Set 12 | pierre
# Processing Record 29 of Set 12 | abyek
# Processing Record 30 of Set 12 | udgir
# Processing Record 31 of Set 12 | shahr-e kord
# Processing Record 32 of Set 12 | manoel urbano
# Processing Record 33 of Set 12 | xining
# Processing Record 34 of Set 12 | calderitas
# Processing Record 35 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 12 | vammala
# Processing Record 37 of Set 12 | derzhavinsk
# Processing Record 38 of Set 12 | pandan
# Processing Record 39 of Set 12 | moree
# Processing Record 40 of Set 12 | barcelona
# Processing Record 41 of Set 12 | key west
# Processing Record 42 of Set 12 | puerto baquerizo moreno
# Processing Record 43 of Set 12 | hwange
# Processing Record 44 of Set 12 | la seyne-sur-mer
# Processing Record 45 of Set 12 | play cu
# City not found. Skipping...
# Processing Record 46 of Set 12 | namibe
# Processing Record 47 of Set 12 | adrar
# Processing Record 48 of Set 12 | forestville
# Processing Record 49 of Set 12 | zhaotong
# Processing Record 50 of Set 12 | pascagoula
# Processing Record 1 of Set 13 | amazar
# Processing Record 2 of Set 13 | shakawe
# Processing Record 3 of Set 13 | mosquera
# Processing Record 4 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 5 of Set 13 | mariental
# Processing Record 6 of Set 13 | ghanzi
# Processing Record 7 of Set 13 | thinadhoo
# Processing Record 8 of Set 13 | erechim
# Processing Record 9 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 13 | teul
# City not found. Skipping...
# Processing Record 12 of Set 13 | salta
# Processing Record 13 of Set 13 | shieli
# Processing Record 14 of Set 13 | binzhou
# Processing Record 15 of Set 13 | staunton
# Processing Record 16 of Set 13 | rosetta
# Processing Record 17 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 13 | klyuchi
# Processing Record 19 of Set 13 | dharmadam
# Processing Record 20 of Set 13 | vangaindrano
# Processing Record 21 of Set 13 | sayyan
# Processing Record 22 of Set 13 | marshall
# Processing Record 23 of Set 13 | venezuela
# Processing Record 24 of Set 13 | puchov
# Processing Record 25 of Set 13 | gusau
# Processing Record 26 of Set 13 | hami
# Processing Record 27 of Set 13 | alofi
# Processing Record 28 of Set 13 | marrakesh
# Processing Record 29 of Set 13 | japura
# Processing Record 30 of Set 13 | kaupanger
# Processing Record 31 of Set 13 | ponta delgada
# Processing Record 32 of Set 13 | buala
# Processing Record 33 of Set 13 | nykoping
# Processing Record 34 of Set 13 | saint-georges
# Processing Record 35 of Set 13 | versalles
# Processing Record 36 of Set 13 | den helder
# Processing Record 37 of Set 13 | candawaga
# City not found. Skipping...
# Processing Record 38 of Set 13 | megion
# Processing Record 39 of Set 13 | kondoa
# Processing Record 40 of Set 13 | riwaka
# Processing Record 41 of Set 13 | mayumba
# Processing Record 42 of Set 13 | ixtapa
# Processing Record 43 of Set 13 | wundanyi
# Processing Record 44 of Set 13 | bac lieu
# Processing Record 45 of Set 13 | berlevag
# Processing Record 46 of Set 13 | saint-augustin
# Processing Record 47 of Set 13 | chekhov
# Processing Record 48 of Set 13 | marsa matruh
# Processing Record 49 of Set 13 | banjar
# Processing Record 50 of Set 13 | mecca
# Processing Record 1 of Set 14 | domoni
# Processing Record 2 of Set 14 | zdunska wola
# Processing Record 3 of Set 14 | san joaquin
# Processing Record 4 of Set 14 | presidente medici
# Processing Record 5 of Set 14 | senigallia
# Processing Record 6 of Set 14 | ha giang
# Processing Record 7 of Set 14 | vilhena
# Processing Record 8 of Set 14 | varkkallai
# Processing Record 9 of Set 14 | songkhla
# Processing Record 10 of Set 14 | beringovskiy
# Processing Record 11 of Set 14 | tutayev
# Processing Record 12 of Set 14 | duluth
# Processing Record 13 of Set 14 | alekseyevka
# Processing Record 14 of Set 14 | opuwo
# Processing Record 15 of Set 14 | chippewa falls
# Processing Record 16 of Set 14 | hobbs
# Processing Record 17 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 18 of Set 14 | hartselle
# Processing Record 19 of Set 14 | rio grande
# Processing Record 20 of Set 14 | tinaquillo
# Processing Record 21 of Set 14 | ligayan
# Processing Record 22 of Set 14 | sterling
# Processing Record 23 of Set 14 | igarka
# Processing Record 24 of Set 14 | homer
# Processing Record 25 of Set 14 | hay river
# Processing Record 26 of Set 14 | yaan
# Processing Record 27 of Set 14 | warri
# Processing Record 28 of Set 14 | port macquarie
# Processing Record 29 of Set 14 | moron
# Processing Record 30 of Set 14 | mazyr
# Processing Record 31 of Set 14 | plonsk
# Processing Record 32 of Set 14 | san luis
# Processing Record 33 of Set 14 | filadelfia
# Processing Record 34 of Set 14 | wajima
# Processing Record 35 of Set 14 | szprotawa
# Processing Record 36 of Set 14 | naujamiestis
# Processing Record 37 of Set 14 | vedasandur
# Processing Record 38 of Set 14 | khed brahma
# Processing Record 39 of Set 14 | waipawa
# Processing Record 40 of Set 14 | kemijarvi
# Processing Record 41 of Set 14 | moerai
# Processing Record 42 of Set 14 | bardstown
# Processing Record 43 of Set 14 | umm kaddadah
# Processing Record 44 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 14 | carman
# Processing Record 46 of Set 14 | hanyang
# Processing Record 47 of Set 14 | alcudia
# Processing Record 48 of Set 14 | yairipok
# Processing Record 49 of Set 14 | sauda
# Processing Record 50 of Set 14 | meulaboh
# Processing Record 1 of Set 15 | krechevitsy
# Processing Record 2 of Set 15 | madaras
# Processing Record 3 of Set 15 | karratha
# Processing Record 4 of Set 15 | peace river
# Processing Record 5 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 6 of Set 15 | villaviciosa
# Processing Record 7 of Set 15 | banda aceh
# Processing Record 8 of Set 15 | labuan
# Processing Record 9 of Set 15 | naifaru
# Processing Record 10 of Set 15 | shibganj
# Processing Record 11 of Set 15 | ouro preto do oeste
# Processing Record 12 of Set 15 | agudos
# Processing Record 13 of Set 15 | hermiston
# Processing Record 14 of Set 15 | san carlos de bariloche
# Processing Record 15 of Set 15 | alwar
# Processing Record 16 of Set 15 | plettenberg bay
# Processing Record 17 of Set 15 | vanavara
# Processing Record 18 of Set 15 | pafos
# Processing Record 19 of Set 15 | qaqortoq
# Processing Record 20 of Set 15 | dudinka
# Processing Record 21 of Set 15 | grande prairie
# -----------------------------------------
# Data Retrieval Complete
# -----------------------------------------

# %%
len(city_data)
# Out:
# 659

# %%
#Add the data to a new DataFrame.
city_weather_df = pd.DataFrame(city_data)
city_weather_df.head()
# Out:
#              City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Elizabeth      ZA -33.9180  25.5701     58.10        94          75
# 1         Teseney      ER  15.1100  36.6575     94.82        34          97
# 2    Saint-Joseph      RE -21.3667  55.6167     75.58        77          37
# 3         Ushuaia      AR -54.8000 -68.3000     33.46        86           0
# 4  Ribeira Grande      PT  38.5167 -28.7000     75.60        94          75
#
#    Wind Speed Current Description
# 0       19.57         shower rain
# 1        6.22     overcast clouds
# 2       10.85    scattered clouds
# 3        0.00           clear sky
# 4       10.36       broken clouds

# %%
output_file_path = "/Users/ttuser/Downloads/Module6/WeatherPy_Database.csv"
city_weather_df.to_csv(output_file_path, index=False)
